# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Churn_Modelling.csv')

# %%
# Business problem:-To find out whether customers will leave the bank or not.

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# missing values check
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# Conversion of categorical data
Geography = pd.get_dummies(data.Geography,drop_first = True)
Gender = pd.get_dummies(data.Gender,drop_first = True)

# %%
Geography
# Out:
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 2 columns]

# %%
Gender
# Out:
#        Male
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9995   True
# 9996   True
# 9997  False
# 9998   True
# 9999  False
#
# [10000 rows x 1 columns]

# %%
data = pd.concat([data,Geography,Gender],axis = 1)

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Germany  Spain   Male
# 0           101348.88       1    False  False  False
# 1           112542.58       0    False   True  False
# 2           113931.57       1    False  False  False
# 3            93826.63       0    False  False  False
# 4            79084.10       0    False   True  False
# ...               ...     ...      ...    ...    ...
# 9995         96270.64       0    False  False   True
# 9996        101699.77       0    False  False   True
# 9997         42085.58       1    False  False  False
# 9998         92888.52       1     True  False   True
# 9999         38190.78       0    False  False  False
#
# [10000 rows x 17 columns]

# %%
data.drop(['Geography', 'Gender'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Germany  \
# 0              1          1               1        101348.88       1    False
# 1              1          0               1        112542.58       0    False
# 2              3          1               0        113931.57       1    False
# 3              2          0               0         93826.63       0    False
# 4              1          1               1         79084.10       0    False
#
#    Spain   Male
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False  False
# 4   True  False

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Germany', 'Spain', 'Male'],
#       dtype='object')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Germany  \
# 0              1          1               1        101348.88       1    False
# 1              1          0               1        112542.58       0    False
# 2              3          1               0        113931.57       1    False
# 3              2          0               0         93826.63       0    False
# 4              1          1               1         79084.10       0    False
#
#    Spain   Male
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False  False
# 4   True  False

# %%
# Creating independent and dependent variable
X = data.loc[:,['CreditScore', 'Age', 'Tenure',
       'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Germany', 'Spain', 'Male']]
y = data.Exited

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
# Traning and testing data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, random_state = 20, stratify = y)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
X_test.shape
# Out:
# (2000, 11)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\jhonw\anaconda3\lib\site-packages (3.15.1)
# Requirement already satisfied: absl-py in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (2.5.0)
# Requirement already satisfied: numpy in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (2.3.5)
# Requirement already satisfied: rich in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (0.19.1)
# Requirement already satisfied: ml-dtypes in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (0.6.0)
# Requirement already satisfied: packaging in c:\users\jhonw\anaconda3\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jhonw\anaconda3\lib\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jhonw\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jhonw\anaconda3\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jhonw\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Defining the model
model  = Sequential()

# %%
model.add(Dense(units = 16, input_dim = 11, activation = 'relu', kernel_initializer = 'he_uniform'))
model.add(Dense(units = 8, activation = 'relu', kernel_initializer = 'he_uniform'))
model.add(Dense(units = 1, activation = 'sigmoid', kernel_initializer = 'glorot_uniform'))
# Out:
# C:\Users\jhonw\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params:
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8627 - loss: 0.3354 - recall: 0.4690 - val_accuracy: 0.8694 - val_loss: 0.3451 - val_recall: 0.5108
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8620 - loss: 0.3350 - recall: 0.4736 - val_accuracy: 0.8700 - val_loss: 0.3451 - val_recall: 0.5231
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8641 - loss: 0.3335 - recall: 0.4728 - val_accuracy: 0.8681 - val_loss: 0.3497 - val_recall: 0.5415
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8617 - loss: 0.3329 - recall: 0.4743 - val_accuracy: 0.8681 - val_loss: 0.3443 - val_recall: 0.5169
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8619 - loss: 0.3329 - recall: 0.4713 - val_accuracy: 0.8675 - val_loss: 0.3454 - val_recall: 0.5292
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8648 - loss: 0.3324 - recall: 0.4782 - val_accuracy: 0.8669 - val_loss: 0.3452 - val_recall: 0.4831
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8642 - loss: 0.3308 - recall: 0.4759 - val_accuracy: 0.8644 - val_loss: 0.3478 - val_recall: 0.5292
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8639 - loss: 0.3313 - recall: 0.4782 - val_accuracy: 0.8656 - val_loss: 0.3451 - val_recall: 0.5046
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8639 - loss: 0.3309 - recall: 0.4820 - val_accuracy: 0.8650 - val_loss: 0.3462 - val_recall: 0.5169

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8555 - loss: 0.3468 - recall: 0.4668
# [0.3467751741409302, 0.8554999828338623, 0.46683046221733093]

# %%
# evaluate the keras model
accuracy = model.evaluate(X_test, y_test)
accuracy
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8555 - loss: 0.3468 - recall: 0.4668
# [0.3467751741409302, 0.8554999828338623, 0.46683046221733093]

# %%
# list all data in history
print(model_history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'recall', 'val_accuracy', 'val_loss', 'val_recall'])

# %%
model_history.history
# Out:
# {'accuracy': [0.5845312476158142,
#   0.7910937666893005,
#   0.8031250238418579,
#   0.8103125095367432,
#   0.8146874904632568,
#   0.8221874833106995,
#   0.8287500143051147,
#   0.8415625095367432,
#   0.8467187285423279,
#   0.8490625023841858,
#   0.8532812595367432,
#   0.8550000190734863,
#   0.8576562404632568,
#   0.8559374809265137,
#   0.8578125238418579,
#   0.8576562404632568,
#   0.8573437333106995,
#   0.858593761920929,
#   0.8600000143051147,
#   0.8615624904632568,
#   0.8615624904632568,
#   0.8600000143051147,
#   0.8612499833106995,
#   0.8618749976158142,
#   0.8629687428474426,
#   0.8626562356948853,
#   0.8620312213897705,
#   0.864062488079071,
#   0.8617187738418579,
#   0.8618749976158142,
#   0.8648437261581421,
#   0.8642187714576721,
#   0.8639062643051147,
#   0.8639062643051147],
#  'loss': [0.7456262707710266,
#   0.48200005292892456,
#   0.44667670130729675,
#   0.4297325015068054,
#   0.41718170046806335,
#   0.4051329493522644,
#   0.3924453854560852,
#   0.38170769810676575,
#   0.3726559579372406,
#   0.36524027585983276,
#   0.3592100441455841,
#   0.3539752662181854,
#   0.3507445454597473,
#   0.34779274463653564,
#   0.34576061367988586,
#   0.344321608543396,
#   0.342779278755188,
#   0.34136494994163513,
#   0.3404728174209595,
#   0.3395790159702301,
#   0.33841609954833984,
#   0.33753663301467896,
#   0.3367350101470947,
#   0.3362636864185333,
#   0.33525484800338745,
#   0.3353722393512726,
#   0.3349779546260834,
#   0.33346596360206604,
#   0.3328784704208374,
#   0.33287569880485535,
#   0.33238762617111206,
#   0.3307953178882599,
#   0.33130982518196106,
#   0.33085742592811584],
#  'recall': [0.42681992053985596,
#   0.1471264362335205,
#   0.17241379618644714,
#   0.20076628029346466,
